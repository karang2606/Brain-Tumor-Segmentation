# %%
from keras.models import Model
from keras.layers import ReLU, Input, Conv3D, MaxPooling3D, concatenate, Conv3DTranspose, BatchNormalization, Dropout, Lambda
from tensorflow.keras.optimizers import Adam
from keras.metrics import MeanIoU

kernel_initializer =  'he_uniform' #Try others if you want

def conv_block(num_filter, in_layer, drop_out):
    
    x = Conv3D(num_filter, (3, 3, 3), kernel_initializer=kernel_initializer, padding='same')(in_layer)
    x = BatchNormalization(axis = -1)(x)
    x = ReLU()(x)
    x = Dropout(drop_out)(x)
    x = Conv3D(num_filter, (3, 3, 3), kernel_initializer=kernel_initializer, padding='same')(x)
    x = BatchNormalization(axis = -1)(x)
    x = ReLU()(x)
    return x

def upConv_block(num_filter, in_layer, concate_list, drop_out):
    
    x = Conv3DTranspose(num_filter, (2, 2, 2), strides=(2, 2, 2), padding='same')(in_layer)
    x = concatenate([x]+concate_list)
    x = ReLU()(x)    
    x = Conv3D(num_filter, (3, 3, 3), kernel_initializer=kernel_initializer, padding='same')(x)
    x = BatchNormalization(axis = -1)(x)
    x = ReLU()(x)    
    x = Dropout(drop_out)(x)
    x = Conv3D(num_filter, (3, 3, 3), kernel_initializer=kernel_initializer, padding='same')(x)
    x = BatchNormalization(axis = -1)(x)
    x = ReLU()(x)
    return x
    
################################################################
def unet_pp(IMG_HEIGHT, IMG_WIDTH, IMG_DEPTH, IMG_CHANNELS, num_classes):
#Build the model
    num_filter = 16
    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_DEPTH, IMG_CHANNELS))
    #s = Lambda(lambda x: x / 255)(inputs)   #No need for this if we normalize our inputs beforehand
    s = inputs

    #Contraction path
    x00 = conv_block(num_filter, s, 0.1)
    p1 = MaxPooling3D((2, 2, 2))(x00)
    
    x10 = conv_block(2*num_filter, p1, 0.1)   
    p2 = MaxPooling3D((2, 2, 2))(x10)

    x01 = upConv_block(num_filter, x10, [x00], 0.2)

    x20 = conv_block(4*num_filter, p2, 0.2)   
    p3 = MaxPooling3D((2, 2, 2))(x20)
    
    x11 = upConv_block(2*num_filter, x20, [x10], 0.2)

    x02 = upConv_block(num_filter, x11, [x01, x00], 0.2)

    x30 = conv_block(4*num_filter, p3, 0.2)   
    p4 = MaxPooling3D(pool_size=(2, 2, 2))(x30)
    
    x21 = upConv_block(4*num_filter, x30, [x20], 0.2)
        
    x12 = upConv_block(4*num_filter, x21, [x11, x10], 0.2)
    
    x03 = upConv_block(num_filter, x12, [x02, x01,  x00], 0.2)
    
    x40 = conv_block(16*num_filter, p4, 0.3)   

    #Expansive path 
    x31 = upConv_block(8*num_filter, x40, [x30], 0.2)
 
    x22 = upConv_block(4*num_filter, x31, [x21, x20], 0.2)
    
    x13 = upConv_block(2*num_filter, x22, [x12, x11, x10], 0.1)
     
    x04 = upConv_block(num_filter, x13, [x03, x02, x01, x00], 0.1)

    outputs = Conv3D(num_classes, (1, 1, 1), activation='sigmoid')(x04)
     
    model = Model(inputs=[inputs], outputs=[outputs])
    #compile model outside of this function to make it flexible. 
    
    return model

#Test if everything is working ok. 
model = unet_pp(IMG_HEIGHT=128, 
                          IMG_WIDTH=128, 
                          IMG_DEPTH=128, 
                          IMG_CHANNELS=4, 
                          num_classes=1)


print(model.input_shape)
print(model.output_shape)
model.summary()
# Out:
# 2022-10-30 11:21:31.716938: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-10-30 11:21:33.051151: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-10-30 11:21:33.051237: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (mig): /proc/driver/nvidia/version does not exist
# 2022-10-30 11:21:33.052258: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (None, 128, 128, 128, 4)
# (None, 128, 128, 128, 1)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 28, 4)]
#
#  conv3d (Conv3D)                (None, 128, 128, 12  1744        ['input_1[0][0]']
#                                 8, 16)
#
#  batch_normalization (BatchNorm  (None, 128, 128, 12  64         ['conv3d[0][0]']
#  alization)                     8, 16)
#
#  re_lu (ReLU)                   (None, 128, 128, 12  0           ['batch_normalization[0][0]']
#                                 8, 16)
#
#  dropout (Dropout)              (None, 128, 128, 12  0           ['re_lu[0][0]']
#                                 8, 16)
#
#  conv3d_1 (Conv3D)              (None, 128, 128, 12  6928        ['dropout[0][0]']
#                                 8, 16)
#
#  batch_normalization_1 (BatchNo  (None, 128, 128, 12  64         ['conv3d_1[0][0]']
#  rmalization)                   8, 16)
#
#  re_lu_1 (ReLU)                 (None, 128, 128, 12  0           ['batch_normalization_1[0][0]']
#                                 8, 16)
#
#  max_pooling3d (MaxPooling3D)   (None, 64, 64, 64,   0           ['re_lu_1[0][0]']
#                                 16)
#
#  conv3d_2 (Conv3D)              (None, 64, 64, 64,   13856       ['max_pooling3d[0][0]']
#                                 32)
#
#  batch_normalization_2 (BatchNo  (None, 64, 64, 64,   128        ['conv3d_2[0][0]']
#  rmalization)                   32)
#
#  re_lu_2 (ReLU)                 (None, 64, 64, 64,   0           ['batch_normalization_2[0][0]']
#                                 32)
#
#  dropout_1 (Dropout)            (None, 64, 64, 64,   0           ['re_lu_2[0][0]']
#                                 32)
#
#  conv3d_3 (Conv3D)              (None, 64, 64, 64,   27680       ['dropout_1[0][0]']
#                                 32)
#
#  batch_normalization_3 (BatchNo  (None, 64, 64, 64,   128        ['conv3d_3[0][0]']
#  rmalization)                   32)
#
#  re_lu_3 (ReLU)                 (None, 64, 64, 64,   0           ['batch_normalization_3[0][0]']
#                                 32)
#
#  max_pooling3d_1 (MaxPooling3D)  (None, 32, 32, 32,   0          ['re_lu_3[0][0]']
#                                 32)
#
#  conv3d_6 (Conv3D)              (None, 32, 32, 32,   55360       ['max_pooling3d_1[0][0]']
#                                 64)
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 32,   256        ['conv3d_6[0][0]']
#  rmalization)                   64)
#
#  re_lu_7 (ReLU)                 (None, 32, 32, 32,   0           ['batch_normalization_6[0][0]']
#                                 64)
#
#  dropout_3 (Dropout)            (None, 32, 32, 32,   0           ['re_lu_7[0][0]']
#                                 64)
#
#  conv3d_7 (Conv3D)              (None, 32, 32, 32,   110656      ['dropout_3[0][0]']
#                                 64)
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 32,   256        ['conv3d_7[0][0]']
#  rmalization)                   64)
#
#  re_lu_8 (ReLU)                 (None, 32, 32, 32,   0           ['batch_normalization_7[0][0]']
#                                 64)
#
#  max_pooling3d_2 (MaxPooling3D)  (None, 16, 16, 16,   0          ['re_lu_8[0][0]']
#                                 64)
#
#  conv3d_12 (Conv3D)             (None, 16, 16, 16,   110656      ['max_pooling3d_2[0][0]']
#                                 64)
#
#  batch_normalization_12 (BatchN  (None, 16, 16, 16,   256        ['conv3d_12[0][0]']
#  ormalization)                  64)
#
#  re_lu_15 (ReLU)                (None, 16, 16, 16,   0           ['batch_normalization_12[0][0]']
#                                 64)
#
#  dropout_6 (Dropout)            (None, 16, 16, 16,   0           ['re_lu_15[0][0]']
#                                 64)
#
#  conv3d_13 (Conv3D)             (None, 16, 16, 16,   110656      ['dropout_6[0][0]']
#                                 64)
#
#  batch_normalization_13 (BatchN  (None, 16, 16, 16,   256        ['conv3d_13[0][0]']
#  ormalization)                  64)
#
#  re_lu_16 (ReLU)                (None, 16, 16, 16,   0           ['batch_normalization_13[0][0]']
#                                 64)
#
#  max_pooling3d_3 (MaxPooling3D)  (None, 8, 8, 8, 64)  0          ['re_lu_16[0][0]']
#
#  conv3d_20 (Conv3D)             (None, 8, 8, 8, 256  442624      ['max_pooling3d_3[0][0]']
#                                 )
#
#  batch_normalization_20 (BatchN  (None, 8, 8, 8, 256  1024       ['conv3d_20[0][0]']
#  ormalization)                  )
#
#  re_lu_26 (ReLU)                (None, 8, 8, 8, 256  0           ['batch_normalization_20[0][0]']
#                                 )
#
#  dropout_10 (Dropout)           (None, 8, 8, 8, 256  0           ['re_lu_26[0][0]']
#                                 )
#
#  conv3d_21 (Conv3D)             (None, 8, 8, 8, 256  1769728     ['dropout_10[0][0]']
#                                 )
#
#  batch_normalization_21 (BatchN  (None, 8, 8, 8, 256  1024       ['conv3d_21[0][0]']
#  ormalization)                  )
#
#  re_lu_27 (ReLU)                (None, 8, 8, 8, 256  0           ['batch_normalization_21[0][0]']
#                                 )
#
#  conv3d_transpose_6 (Conv3DTran  (None, 16, 16, 16,   262272     ['re_lu_27[0][0]']
#  spose)                         128)
#
#  concatenate_6 (Concatenate)    (None, 16, 16, 16,   0           ['conv3d_transpose_6[0][0]',
#                                 192)                              're_lu_16[0][0]']
#
#  conv3d_transpose_3 (Conv3DTran  (None, 32, 32, 32,   32832      ['re_lu_16[0][0]']
#  spose)                         64)
#
#  re_lu_28 (ReLU)                (None, 16, 16, 16,   0           ['concatenate_6[0][0]']
#                                 192)
#
#  concatenate_3 (Concatenate)    (None, 32, 32, 32,   0           ['conv3d_transpose_3[0][0]',
#                                 128)                              're_lu_8[0][0]']
#
#  conv3d_transpose_1 (Conv3DTran  (None, 64, 64, 64,   16416      ['re_lu_8[0][0]']
#  spose)                         32)
#
#  conv3d_22 (Conv3D)             (None, 16, 16, 16,   663680      ['re_lu_28[0][0]']
#                                 128)
#
#  re_lu_17 (ReLU)                (None, 32, 32, 32,   0           ['concatenate_3[0][0]']
#                                 128)
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 64,   0           ['conv3d_transpose_1[0][0]',
#                                 64)                               're_lu_3[0][0]']
#
#  conv3d_transpose (Conv3DTransp  (None, 128, 128, 12  4112       ['re_lu_3[0][0]']
#  ose)                           8, 16)
#
#  batch_normalization_22 (BatchN  (None, 16, 16, 16,   512        ['conv3d_22[0][0]']
#  ormalization)                  128)
#
#  conv3d_14 (Conv3D)             (None, 32, 32, 32,   221248      ['re_lu_17[0][0]']
#                                 64)
#
#  re_lu_9 (ReLU)                 (None, 64, 64, 64,   0           ['concatenate_1[0][0]']
#                                 64)
#
#  concatenate (Concatenate)      (None, 128, 128, 12  0           ['conv3d_transpose[0][0]',
#                                 8, 32)                            're_lu_1[0][0]']
#
#  re_lu_29 (ReLU)                (None, 16, 16, 16,   0           ['batch_normalization_22[0][0]']
#                                 128)
#
#  batch_normalization_14 (BatchN  (None, 32, 32, 32,   256        ['conv3d_14[0][0]']
#  ormalization)                  64)
#
#  conv3d_8 (Conv3D)              (None, 64, 64, 64,   55328       ['re_lu_9[0][0]']
#                                 32)
#
#  re_lu_4 (ReLU)                 (None, 128, 128, 12  0           ['concatenate[0][0]']
#                                 8, 32)
#
#  dropout_11 (Dropout)           (None, 16, 16, 16,   0           ['re_lu_29[0][0]']
#                                 128)
#
#  re_lu_18 (ReLU)                (None, 32, 32, 32,   0           ['batch_normalization_14[0][0]']
#                                 64)
#
#  batch_normalization_8 (BatchNo  (None, 64, 64, 64,   128        ['conv3d_8[0][0]']
#  rmalization)                   32)
#
#  conv3d_4 (Conv3D)              (None, 128, 128, 12  13840       ['re_lu_4[0][0]']
#                                 8, 16)
#
#  conv3d_23 (Conv3D)             (None, 16, 16, 16,   442496      ['dropout_11[0][0]']
#                                 128)
#
#  dropout_7 (Dropout)            (None, 32, 32, 32,   0           ['re_lu_18[0][0]']
#                                 64)
#
#  re_lu_10 (ReLU)                (None, 64, 64, 64,   0           ['batch_normalization_8[0][0]']
#                                 32)
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 12  64         ['conv3d_4[0][0]']
#  rmalization)                   8, 16)
#
#  batch_normalization_23 (BatchN  (None, 16, 16, 16,   512        ['conv3d_23[0][0]']
#  ormalization)                  128)
#
#  conv3d_15 (Conv3D)             (None, 32, 32, 32,   110656      ['dropout_7[0][0]']
#                                 64)
#
#  dropout_4 (Dropout)            (None, 64, 64, 64,   0           ['re_lu_10[0][0]']
#                                 32)
#
#  re_lu_5 (ReLU)                 (None, 128, 128, 12  0           ['batch_normalization_4[0][0]']
#                                 8, 16)
#
#  re_lu_30 (ReLU)                (None, 16, 16, 16,   0           ['batch_normalization_23[0][0]']
#                                 128)
#
#  batch_normalization_15 (BatchN  (None, 32, 32, 32,   256        ['conv3d_15[0][0]']
#  ormalization)                  64)
#
#  conv3d_9 (Conv3D)              (None, 64, 64, 64,   27680       ['dropout_4[0][0]']
#                                 32)
#
#  dropout_2 (Dropout)            (None, 128, 128, 12  0           ['re_lu_5[0][0]']
#                                 8, 16)
#
#  conv3d_transpose_7 (Conv3DTran  (None, 32, 32, 32,   65600      ['re_lu_30[0][0]']
#  spose)                         64)
#
#  re_lu_19 (ReLU)                (None, 32, 32, 32,   0           ['batch_normalization_15[0][0]']
#                                 64)
#
#  batch_normalization_9 (BatchNo  (None, 64, 64, 64,   128        ['conv3d_9[0][0]']
#  rmalization)                   32)
#
#  conv3d_5 (Conv3D)              (None, 128, 128, 12  6928        ['dropout_2[0][0]']
#                                 8, 16)
#
#  concatenate_7 (Concatenate)    (None, 32, 32, 32,   0           ['conv3d_transpose_7[0][0]',
#                                 192)                              're_lu_19[0][0]',
#                                                                   're_lu_8[0][0]']
#
#  conv3d_transpose_4 (Conv3DTran  (None, 64, 64, 64,   32832      ['re_lu_19[0][0]']
#  spose)                         64)
#
#  re_lu_11 (ReLU)                (None, 64, 64, 64,   0           ['batch_normalization_9[0][0]']
#                                 32)
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 12  64         ['conv3d_5[0][0]']
#  rmalization)                   8, 16)
#  re_lu_31 (ReLU)                (None, 32, 32, 32,   0           ['concatenate_7[0][0]']
#                                 192)
#
#  concatenate_4 (Concatenate)    (None, 64, 64, 64,   0           ['conv3d_transpose_4[0][0]',
#                                 128)                              're_lu_11[0][0]',
#                                                                   're_lu_3[0][0]']
#
#  conv3d_transpose_2 (Conv3DTran  (None, 128, 128, 12  4112       ['re_lu_11[0][0]']
#  spose)                         8, 16)
#
#  re_lu_6 (ReLU)                 (None, 128, 128, 12  0           ['batch_normalization_5[0][0]']
#                                 8, 16)
#
#  conv3d_24 (Conv3D)             (None, 32, 32, 32,   331840      ['re_lu_31[0][0]']
#                                 64)
#
#  re_lu_20 (ReLU)                (None, 64, 64, 64,   0           ['concatenate_4[0][0]']
#                                 128)
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 12  0           ['conv3d_transpose_2[0][0]',
#                                 8, 48)                            're_lu_6[0][0]',
#                                                                   're_lu_1[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 32, 32, 32,   256        ['conv3d_24[0][0]']
#  ormalization)                  64)
#
#  conv3d_16 (Conv3D)             (None, 64, 64, 64,   221248      ['re_lu_20[0][0]']
#                                 64)
#
#  re_lu_12 (ReLU)                (None, 128, 128, 12  0           ['concatenate_2[0][0]']
#                                 8, 48)
#
#  re_lu_32 (ReLU)                (None, 32, 32, 32,   0           ['batch_normalization_24[0][0]']
#                                 64)
#
#  batch_normalization_16 (BatchN  (None, 64, 64, 64,   256        ['conv3d_16[0][0]']
#  ormalization)                  64)
#
#  conv3d_10 (Conv3D)             (None, 128, 128, 12  20752       ['re_lu_12[0][0]']
#                                 8, 16)
#
#  dropout_12 (Dropout)           (None, 32, 32, 32,   0           ['re_lu_32[0][0]']
#                                 64)
#
#  re_lu_21 (ReLU)                (None, 64, 64, 64,   0           ['batch_normalization_16[0][0]']
#                                 64)
#
#  batch_normalization_10 (BatchN  (None, 128, 128, 12  64         ['conv3d_10[0][0]']
#  ormalization)                  8, 16)
#
#  conv3d_25 (Conv3D)             (None, 32, 32, 32,   110656      ['dropout_12[0][0]']
#                                 64)
#
#  dropout_8 (Dropout)            (None, 64, 64, 64,   0           ['re_lu_21[0][0]']
#                                 64)
#
#  re_lu_13 (ReLU)                (None, 128, 128, 12  0           ['batch_normalization_10[0][0]']
#                                 8, 16)
#
#  batch_normalization_25 (BatchN  (None, 32, 32, 32,   256        ['conv3d_25[0][0]']
#  ormalization)                  64)
#
#  conv3d_17 (Conv3D)             (None, 64, 64, 64,   110656      ['dropout_8[0][0]']
#                                 64)
#
#  dropout_5 (Dropout)            (None, 128, 128, 12  0           ['re_lu_13[0][0]']
#                                 8, 16)
#
#  re_lu_33 (ReLU)                (None, 32, 32, 32,   0           ['batch_normalization_25[0][0]']
#                                 64)
#
#  batch_normalization_17 (BatchN  (None, 64, 64, 64,   256        ['conv3d_17[0][0]']
#  ormalization)                  64)
#
#  conv3d_11 (Conv3D)             (None, 128, 128, 12  6928        ['dropout_5[0][0]']
#                                 8, 16)
#
#  conv3d_transpose_8 (Conv3DTran  (None, 64, 64, 64,   16416      ['re_lu_33[0][0]']
#  spose)                         32)
#
#  re_lu_22 (ReLU)                (None, 64, 64, 64,   0           ['batch_normalization_17[0][0]']
#                                 64)
#  batch_normalization_11 (BatchN  (None, 128, 128, 12  64         ['conv3d_11[0][0]']
#  ormalization)                  8, 16)
#
#  concatenate_8 (Concatenate)    (None, 64, 64, 64,   0           ['conv3d_transpose_8[0][0]',
#                                 160)                              're_lu_22[0][0]',
#                                                                   're_lu_11[0][0]',
#                                                                   're_lu_3[0][0]']
#
#  conv3d_transpose_5 (Conv3DTran  (None, 128, 128, 12  8208       ['re_lu_22[0][0]']
#  spose)                         8, 16)
#
#  re_lu_14 (ReLU)                (None, 128, 128, 12  0           ['batch_normalization_11[0][0]']
#                                 8, 16)
#
#  re_lu_34 (ReLU)                (None, 64, 64, 64,   0           ['concatenate_8[0][0]']
#                                 160)
#
#  concatenate_5 (Concatenate)    (None, 128, 128, 12  0           ['conv3d_transpose_5[0][0]',
#                                 8, 64)                            're_lu_14[0][0]',
#                                                                   're_lu_6[0][0]',
#                                                                   're_lu_1[0][0]']
#
#  conv3d_26 (Conv3D)             (None, 64, 64, 64,   138272      ['re_lu_34[0][0]']
#                                 32)
#
#  re_lu_23 (ReLU)                (None, 128, 128, 12  0           ['concatenate_5[0][0]']
#                                 8, 64)
#
#  batch_normalization_26 (BatchN  (None, 64, 64, 64,   128        ['conv3d_26[0][0]']
#  ormalization)                  32)
#
#  conv3d_18 (Conv3D)             (None, 128, 128, 12  27664       ['re_lu_23[0][0]']
#                                 8, 16)
#
#  re_lu_35 (ReLU)                (None, 64, 64, 64,   0           ['batch_normalization_26[0][0]']
#                                 32)
#
#  batch_normalization_18 (BatchN  (None, 128, 128, 12  64         ['conv3d_18[0][0]']
#  ormalization)                  8, 16)
#
#  dropout_13 (Dropout)           (None, 64, 64, 64,   0           ['re_lu_35[0][0]']
#                                 32)
#
#  re_lu_24 (ReLU)                (None, 128, 128, 12  0           ['batch_normalization_18[0][0]']
#                                 8, 16)
#
#  conv3d_27 (Conv3D)             (None, 64, 64, 64,   27680       ['dropout_13[0][0]']
#                                 32)
#
#  dropout_9 (Dropout)            (None, 128, 128, 12  0           ['re_lu_24[0][0]']
#                                 8, 16)
#
#  batch_normalization_27 (BatchN  (None, 64, 64, 64,   128        ['conv3d_27[0][0]']
#  ormalization)                  32)
#
#  conv3d_19 (Conv3D)             (None, 128, 128, 12  6928        ['dropout_9[0][0]']
#                                 8, 16)
#
#  re_lu_36 (ReLU)                (None, 64, 64, 64,   0           ['batch_normalization_27[0][0]']
#                                 32)
#
#  batch_normalization_19 (BatchN  (None, 128, 128, 12  64         ['conv3d_19[0][0]']
#  ormalization)                  8, 16)
#
#  conv3d_transpose_9 (Conv3DTran  (None, 128, 128, 12  4112       ['re_lu_36[0][0]']
#  spose)                         8, 16)
#
#  re_lu_25 (ReLU)                (None, 128, 128, 12  0           ['batch_normalization_19[0][0]']
#                                 8, 16)
#
#  concatenate_9 (Concatenate)    (None, 128, 128, 12  0           ['conv3d_transpose_9[0][0]',
#                                 8, 80)                            're_lu_25[0][0]',
#                                                                   're_lu_14[0][0]',
#                                                                   're_lu_6[0][0]',
#                                                                   're_lu_1[0][0]']
#
#  re_lu_37 (ReLU)                (None, 128, 128, 12  0           ['concatenate_9[0][0]']
#                                 8, 80)
#
#  conv3d_28 (Conv3D)             (None, 128, 128, 12  34576       ['re_lu_37[0][0]']
#                                 8, 16)
#
#  batch_normalization_28 (BatchN  (None, 128, 128, 12  64         ['conv3d_28[0][0]']
#  ormalization)                  8, 16)
#
#  re_lu_38 (ReLU)                (None, 128, 128, 12  0           ['batch_normalization_28[0][0]']
#                                 8, 16)
#
#  dropout_14 (Dropout)           (None, 128, 128, 12  0           ['re_lu_38[0][0]']
#                                 8, 16)
#
#  conv3d_29 (Conv3D)             (None, 128, 128, 12  6928        ['dropout_14[0][0]']
#                                 8, 16)
#
#  batch_normalization_29 (BatchN  (None, 128, 128, 12  64         ['conv3d_29[0][0]']
#  ormalization)                  8, 16)
#
#  re_lu_39 (ReLU)                (None, 128, 128, 12  0           ['batch_normalization_29[0][0]']
#                                 8, 16)
#
#  conv3d_30 (Conv3D)             (None, 128, 128, 12  17          ['re_lu_39[0][0]']
#                                 8, 1)
#
# ==================================================================================================
# Total params: 5,689,841
# Trainable params: 5,686,321
# Non-trainable params: 3,520
# __________________________________________________________________________________________________
